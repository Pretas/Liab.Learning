# %%
# !pip install pymysql
# !pip install pymssql

import LibData
import LibUtils
import LibML
import LibFile
import LibEE

import pandas as pd
import numpy as np

jobName = '201216_Train_split1'

# 단계6. 임베딩2 :  원핫 -> 머니니스 -> 가입나이 -> 금리축소 -> 임베딩_상품코드 -> 임베딩_경과기간x현재나이 -> 스케일러
x, y = LibData.GetXYBase(jobName)
x = LibData.GetMoneyness(x)
x = LibData.GetAttainedAge(x)
x = LibData.GetIrReduction(x)
x = LibEE.GetX_Inter_EM_AA_old(x)
x = LibEE.GetXEmbApplied(3, x, y, ['ProdCode', 'Inter_EM_AA'])
scaler, x = LibUtils.ScaleStandard(x)

from sklearn.ensemble import RandomForestRegressor

# 10개
x_new = x[['Sex', 'Prem', 'PremYr', 'AccumPrem', 'StartAge', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_01', 'ee_Inter_EM_AA_01']]
model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
print(LibML.GetPred(x_new, y, model, 5))

# 11개
x_new = x[['Sex', 'Prem', 'PremYr', 'AccumPrem', 'StartAge', 'FundAllo03', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_01', 'ee_Inter_EM_AA_01']]
model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
print(LibML.GetPred(x_new, y, model, 5))

# 12개
x_new = x[['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'StartAge', 'FundAllo03', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_01', 'ee_Inter_EM_AA_01']]
model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
print(LibML.GetPred(x_new, y, model, 5))

# 13개
x_new = x[['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundAllo03', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_01', 'ee_Inter_EM_AA_01']]
model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
print(LibML.GetPred(x_new, y, model, 5))


# # 14개
# x_new = x[['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundAllo03', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_01', 'ee_Inter_EM_AA_01']]
# model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
# print(LibML.GetPred(x_new, y, model, 5))

# # 15개
# x_new = x[['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundAllo03', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_01', 'ee_Inter_EM_AA_01']]
# model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
# print(LibML.GetPred(x_new, y, model, 5))

# # 16개
# x_new = x[['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_01', 'ee_Inter_EM_AA_01']]
# model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
# print(LibML.GetPred(x_new, y, model, 5))

# # 17개
# x_new = x[['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_01', 'ee_ProdCode_02']]
# model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
# print(LibML.GetPred(x_new, y, model, 5))

# # 18개
# x_new = x[['Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundVal02', 'FundVal03', 'FundAllo02', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_02']]
# model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
# print(LibML.GetPred(x_new, y, model, 5))

# # 19개
# x_new = x[['Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundVal02', 'FundVal03', 'FundAllo01', 'FundAllo02', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_02']]
# model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
# print(LibML.GetPred(x_new, y, model, 5))

# # 20개
# x_new = x[['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundVal02', 'FundVal03', 'FundAllo01', 'FundAllo02', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_02']]
# model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
# print(LibML.GetPred(x_new, y, model, 5))

# # 21개
# x_new = x[['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundVal02', 'FundVal03', 'FundAllo01', 'FundAllo02', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_02', 'ee_Inter_EM_AA_01']]
# model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
# print(LibML.GetPred(x_new, y, model, 5))

# # 22개
# x_new = x[['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundVal02', 'FundVal03', 'FundAllo01', 'FundAllo02', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_02', 'ee_Inter_EM_AA_01', 'ee_Inter_EM_AA_02']]
# model = RandomForestRegressor(n_estimators = 1000, min_samples_leaf = 1, max_features=len(x_new.columns))
# print(LibML.GetPred(x_new, y, model, 5))

LibUtils.ELoop()
# Out:
# ...
#      |████████████████████████████████| 51kB 4.5MB/s
# ...
#      |████████████████████████████████| 1.3MB 8.6MB/s
# ...
# start learning 1 2021-01-05 09:51... end learning 2021-01-05 10:03
# start learning 2 2021-01-05 10:03... end learning 2021-01-05 10:14
# start learning 3 2021-01-05 10:14... end learning 2021-01-05 10:26
# start learning 4 2021-01-05 10:26... end learning 2021-01-05 10:38
# start learning 5 2021-01-05 10:38... end learning 2021-01-05 10:50
# [165.22, 0.1976, 0.9416]
# start learning 1 2021-01-05 10:50... end learning 2021-01-05 11:02
# start learning 2 2021-01-05 11:02... end learning 2021-01-05 11:15
# start learning 3 2021-01-05 11:15... end learning 2021-01-05 11:28
# start learning 4 2021-01-05 11:28... end learning 2021-01-05 11:40
# start learning 5 2021-01-05 11:40... end learning 2021-01-05 11:53
# [126.93, 0.1518, 0.9477]
# start learning 1 2021-01-05 11:53... end learning 2021-01-05 12:07
# start learning 2 2021-01-05 12:07... end learning 2021-01-05 12:20
# ...
