# %%
# !pip install pymysql
# !pip install pymssql

import LibData
import LibUtils
import LibML
import LibFile
import LibEE

import pandas as pd
import numpy as np

jobName = '201216_Train_split1'

# 단계6. 임베딩2 :  원핫 -> 머니니스 -> 가입나이 -> 금리축소 -> 임베딩_상품코드 -> 임베딩_경과기간x현재나이 -> 스케일러
x, y = LibData.GetXYBase(jobName)
x = LibData.GetMoneyness(x)
x = LibData.GetAttainedAge(x)
x = LibData.GetIrReduction(x)
x = LibEE.GetX_Inter_EM_AA(x)
x = LibEE.GetXEmbApplied(3, x, y, ['ProdCode', 'Inter_EM_AA'])
scaler, x = LibUtils.ScaleStandard(x)

colsSelected = ['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_01', 'ee_ProdCode_02']
x = x[colsSelected]
# Out:
# Collecting pymysql
#   Downloading https://files.pythonhosted.org/packages/7e/06/59223a2e0bbe2c830ad5e90c09d781626b5e7f840404a02838b502045413/PyMySQL-1.0.0-py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 2.7MB/s
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.0
# Collecting pymssql
#   Downloading https://files.pythonhosted.org/packages/fe/aa/59c7c8a2cf1ef0726cd4c64bff7072147db8cbb6b4379fb0c3d7c67331b9/pymssql-2.1.5-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 5.3MB/s
# Installing collected packages: pymssql
# Successfully installed pymssql-2.1.5

# %%
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
import LibML

# 탐색 대상 함수 (XGBRegressor)
def XGB_cv(learning_rate, n_estimators, max_depth, subsample,min_child_weight, gamma):

    # 모델 정의
    model = XGBRegressor(learning_rate=learning_rate,
                         n_estimators=int(n_estimators),
                         max_depth=int(max_depth),
                         subsample=subsample,                         
                         min_child_weight=min_child_weight,
                         gamma = gamma,
                         nthread=2,
                         objective = 'reg:squarederror')
    
    # 모델 훈련 & 예측값
    scores = LibML.GetPred(x,y,model,2)
    
    # return negative mae
    return -scores[0]

# %%
#  bayesian-optimization 라이브러리의 BayesianOptimization 클래스 import
# !pip install bayesian-optimization
from bayes_opt import BayesianOptimization
import numpy as np

# 실험해보고자하는 hyperparameter 집합
# pbounds = { 'learning_rate': (0.01, 0.2),
#             'n_estimators': (5000, 10000),
#             'max_depth': (3, 10),
#             'subsample': (0, 1),
#             'colsample_bytree' : (0, 1),
#             'min_child_weight': (0, 4),
#             'max_delta_step' : (0, 1),
#             'gamma': (0, 100)
#             }

# 2차 
pbounds = {'gamma' : (0.0, 0.01),           
     'learning_rate': (0.0, 0.2),            
            'max_depth': (5, 15),
            'min_child_weight': (0, 4),
           'n_estimators': (3000, 5000),
           'subsample': (0.2, 0.7),
            }

# Bayesian optimization 객체 생성
# f : 탐색 대상 함수, pbounds : hyperparameter 집합
# verbose = 2 항상 출력, verbose = 1 최댓값일 때 출력, verbose = 0 출력 안함
# random_state : Bayesian Optimization 상의 랜덤성이 존재하는 부분을 통제 
bo=BayesianOptimization(f=XGB_cv, pbounds=pbounds, verbose=2, random_state=1)

# 메소드를 이용해 최대화 과정 수행
# init_points :  초기 Random Search 갯수
# n_iter : 반복 횟수 (몇개의 입력값-함숫값 점들을 확인할지! 많을 수록 정확한 값을 얻을 수 있다.)
# acq : Acquisition Function들 중 Expected Improvement(EI) 를 사용
# xi : exploration 강도 (기본값은 0.0)

bo.maximize(init_points=2, n_iter=70, acq='ei', xi=0.01)

# ‘iter’는 반복 회차, ‘target’은 목적 함수의 값, 나머지는 입력값을 나타냅니다. 
# 현재 회차 이전까지 조사된 함숫값들과 비교하여, 현재 회차에 최댓값이 얻어진 경우, 
# bayesian-optimization 라이브러리는 이를 자동으로 다른 색 글자로 표시하는 것을 확인할 수 있습니다

# 찾은 파라미터 값 확인
print(bo.max)

LibUtils.ELoop()
# Out:
# Requirement already satisfied: bayesian-optimization in /usr/local/lib/python3.6/dist-packages (1.2.0)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.19.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.0.0)
# ERROR: Operation cancelled by user
# |   iter    |  target   |   gamma   | learni... | max_depth | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/bayes_opt/target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (0.00417022004702574, 0.14406489868843161, 5.001143748173449, 1.209330290527359, 3293.5117816342263, 0.2461692973843989)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c7836bffc7c2> in <module>()
#      36 # xi : exploration 강도 (기본값은 0.0)
#      37
# ---> 38 bo.maximize(init_points=2, n_iter=70, acq='ei', xi=0.01)
#      39
#      40 # ‘iter’는 반복 회차, ‘target’은 목적 함수의 값, 나머지는 입력값을 나타냅니다.
#
# /usr/local/lib/python3.6/dist-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# /usr/local/lib/python3.6/dist-packages/bayes_opt/bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# /usr/local/lib/python3.6/dist-packages/bayes_opt/target_space.py in probe(self, params)
#     192         except KeyError:
#     193             params = dict(zip(self._keys, x))
# --> 194             target = self.target_func(**params)
#     195             self.register(x, target)
#     196         return target
#
# <ipython-input-2-540f65815a59> in XGB_cv(learning_rate, n_estimators, max_depth, subsample, min_child_weight, gamma)
#      17
#      18     # 모델 훈련 & 예측값
# ---> 19     scores = LibML.GetPred(x,y,model,2)
#      20
#      21     # return negative mae
#
# /content/LibML.py in GetPred(x, y, model, cvCnt)
#      34         # fee 학습 및 예측
#      35         yName = 'pv_fee'
# ---> 36         model.fit(xTrain, yTrain[yName])
#      37         pred_f = pd.Series(model.predict(xTest), index=yTest.index)
#      38
#
# /usr/local/lib/python3.6/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     394                               evals_result=evals_result, obj=obj, feval=feval,
#     395                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 396                               callbacks=callbacks)
#     397
#     398         if evals_result:
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:
