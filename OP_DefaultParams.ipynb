# %%
from sklearn.svm import SVR
import time


# jobName = '201216_Train_pilot'
jobName = '201216_Train_split1'
x, y = LibData.GetXY_s_o(jobName)

def Fit(x,y, model):
    t1 =time.time()
    scores = LibML.GetScoresHoldOut(x,y,model, 0.2)
    t2=time.time()
    print(model.get_params())
    print(scores ,', dur time : ', str(t2-t1), '\n')

model = SVR(kernel='rbf', C=1, gamma=0.01); Fit(x,y,model)
model = SVR(kernel='rbf', C=1, gamma=0.1); Fit(x,y,model)

model = SVR(kernel='rbf', C=10, gamma=0.01); Fit(x,y,model)
model = SVR(kernel='rbf', C=10, gamma=0.1); Fit(x,y,model)

model = SVR(kernel='rbf', C=50, gamma=0.01); Fit(x,y,model)
model = SVR(kernel='rbf', C=50, gamma=0.1); Fit(x,y,model) #Best : 3시간

LibUtils.ELoop()


# {'C': 1, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# [623.07, 0.7408, 0.1829] , dur time :  3334.00275182724 

# {'C': 1, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# [595.16, 0.7138, 0.2338] , dur time :  2092.25896024704 

# {'C': 10, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# [474.2, 0.5652, 0.4077] , dur time :  2052.3410139083862 

# {'C': 10, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# [435.78, 0.5241, 0.4284] , dur time :  2375.8137419223785 

# {'C': 50, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# [397.97, 0.4771, 0.5315] , dur time :  1961.5556116104126 

# {'C': 50, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.1, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# [327.84, 0.3922, 0.5959] , dur time :  10870.010012626648
