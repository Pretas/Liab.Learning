# %%
# !pip install pymysql
# !pip install pymssql

import LibData
import LibUtils
import LibML
import LibFile

import pandas as pd
import numpy as np

x = pd.read_csv('x.csv')
y = pd.read_csv('y.csv')
# Out:
# ...
#      |████████████████████████████████| 51kB 2.6MB/s
# ...
#      |████████████████████████████████| 1.3MB 4.3MB/s
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=1000, min_samples_leaf=1)

# %%
# f_regression

top20 = ['Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'FundVal02', 'FundVal03',
       'FundAllo02', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness',
       'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_01', 'ee_ProdCode_02',
       'ee_Inter_EM_AA_00', 'ee_Inter_EM_AA_01', 'ee_Inter_EM_AA_02']

x_selected = x[top20]
print(x_selected.columns)
print(LibML.GetPred(x_selected, y, model, 5))
# Out:
# Index(['Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'FundVal02', 'FundVal03',
#        'FundAllo02', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness',
#        'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_01', 'ee_ProdCode_02',
#        'ee_Inter_EM_AA_00', 'ee_Inter_EM_AA_01', 'ee_Inter_EM_AA_02'],
#       dtype='object')
# start learning 1 2021-01-06 14:34... end learning 2021-01-06 15:14
# start learning 2 2021-01-06 15:14... end learning 2021-01-06 15:54
# start learning 3 2021-01-06 15:54... end learning 2021-01-06 16:36
# start learning 4 2021-01-06 16:36... end learning 2021-01-06 17:17
# start learning 5 2021-01-06 17:17... end learning 2021-01-06 17:59
# [266.74, 0.3189, 0.8574]

# %%
# MI

top20 = ['AccumPrem', 'IR12', 'IR14', 'Moneyness', 'IR09', 'IR06', 'ee_ProdCode_01',
 'ee_ProdCode_00', 'ee_ProdCode_02', 'ee_Inter_EM_AA_00', 'ee_Inter_EM_AA_02',
 'ee_Inter_EM_AA_01', 'Prem', 'FundVal01', 'AttainedAge', 'ContAmt', 'StartAge',
 'ElapsedMth', 'FundVal02', 'FundVal03']

x_selected = x[top20]
print(x_selected.columns)
print(LibML.GetPred(x_selected, y, model, 5))
# Out:
# Index(['AccumPrem', 'IR12', 'IR14', 'Moneyness', 'IR09', 'IR06',
#        'ee_ProdCode_01', 'ee_ProdCode_00', 'ee_ProdCode_02',
#        'ee_Inter_EM_AA_00', 'ee_Inter_EM_AA_02', 'ee_Inter_EM_AA_01', 'Prem',
#        'FundVal01', 'AttainedAge', 'ContAmt', 'StartAge', 'ElapsedMth',
#        'FundVal02', 'FundVal03'],
#       dtype='object')
# start learning 1 2021-01-06 13:25... end learning 2021-01-06 13:57
# start learning 2 2021-01-06 13:57... end learning 2021-01-06 14:28
# start learning 3 2021-01-06 14:28... end learning 2021-01-06 15:00
# start learning 4 2021-01-06 15:00... end learning 2021-01-06 15:31
# start learning 5 2021-01-06 15:31... end learning 2021-01-06 16:03
# [207.37, 0.2479, 0.9161]

# %%
# lasso

top20 = ['ElapsedMth','Sex','Prem','PremYr','AccumPrem','ContAmt','FundVal01',
 'FundVal02','FundVal03','FundAllo01','FundAllo03','IR12','IR14',
 'Moneyness','AttainedAge','ee_ProdCode_01','ee_ProdCode_02',
 'ee_Inter_EM_AA_00','ee_Inter_EM_AA_01','ee_Inter_EM_AA_02']

x_selected = x[top20]
print(x_selected.columns)
print(LibML.GetPred(x_selected, y, model, 5))
# Out:
# Index(['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt',
#        'FundVal01', 'FundVal02', 'FundVal03', 'FundAllo01', 'FundAllo03',
#        'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_01',
#        'ee_ProdCode_02', 'ee_Inter_EM_AA_00', 'ee_Inter_EM_AA_01',
#        'ee_Inter_EM_AA_02'],
#       dtype='object')
# start learning 1 2021-01-06 16:03... end learning 2021-01-06 16:34
# start learning 2 2021-01-06 16:34... end learning 2021-01-06 17:05
# start learning 3 2021-01-06 17:05... end learning 2021-01-06 17:36
# start learning 4 2021-01-06 17:36... end learning 2021-01-06 18:07
# start learning 5 2021-01-06 18:07... end learning 2021-01-06 18:38
# [197.09, 0.2357, 0.8846]

# %%
# rf

top20 = ['AccumPrem','Moneyness','AttainedAge','ee_Inter_EM_AA_01','Prem',
 'StartAge','IR14','IR12','ee_ProdCode_01','ee_ProdCode_02','ElapsedMth',
 'ee_Inter_EM_AA_00','ee_Inter_EM_AA_02','PremYr','Sex','ee_ProdCode_00',
 'FundVal01','FundVal03','FundVal02','ContAmt']

x_selected = x[top20]
print(x_selected.columns)
print(LibML.GetPred(x_selected, y, model, 5))

# %%
# xgboost

top20 = ['ContAmt', 'AccumPrem', 'IR12', 'ee_Inter_EM_AA_01', 'ElapsedMth',
 'ee_ProdCode_01', 'PremYr', 'Moneyness', 'Prem', 'AttainedAge', 'Sex',
 'StartAge', 'ee_Inter_EM_AA_02', 'ee_ProdCode_02', 'ee_Inter_EM_AA_00',
 'ee_ProdCode_00', 'FundVal01', 'FundVal03', 'FundAllo03', 'IR09']

x_selected = x[top20]
print(x_selected.columns)
print(LibML.GetPred(x_selected, y, model, 5))

# %%
# sffs

top20 = ['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundVal01', 'FundAllo01', 'FundAllo02', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_01', 'ee_ProdCode_02']


x_selected = x[top20]
print(x_selected.columns)
print(LibML.GetPred(x_selected, y, model, 5))

# %%
# sfbs

top20 = ['ElapsedMth', 'Sex', 'Prem', 'PremYr', 'AccumPrem', 'ContAmt', 'StartAge', 'FundVal02', 'FundVal03', 'FundAllo01', 'FundAllo02', 'FundAllo03', 'IR06', 'IR09', 'IR12', 'IR14', 'Moneyness', 'AttainedAge', 'ee_ProdCode_00', 'ee_ProdCode_02']


x_selected = x[top20]
print(x_selected.columns)
print(LibML.GetPred(x_selected, y, model, 5))

# %%
LibUtils.ELoop()
# Out:
# start empty loop...................................................................................................................................................................................................................................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f71d9f72996d> in <module>()
# ----> 1 LibUtils.ELoop()
#
# /content/LibUtils.py in ELoop()
#      51     print("start empty loop.", end='')
#      52     while True:
# ---> 53         time.sleep(60); print(".", end='') # 5초 슬립, press ctr+c to out
#      54
#      55
#
# KeyboardInterrupt:
